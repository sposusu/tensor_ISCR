# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np
import h5py

# %%
h5_handle = h5py.File('debug_visualize.h5','r')
feature = h5_handle['features'][:]
tsne_feature = h5_handle['tsne_features'][:]
actions = h5_handle['actions'][:]

# %%
print("Feature shape {}".format(feature.shape))
# Out:
# Feature shape (864, 87)

# %%
plt.figure()
plt.scatter(tsne_feature[:,0],tsne_feature[:,1],s=5,alpha=0.5,c=actions)
plt.colorbar()

# %%
set(actions.tolist())
# Out:
# {4}
